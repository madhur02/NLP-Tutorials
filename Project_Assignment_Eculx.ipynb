# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

import seaborn as sns

# %%
#path = 'C:\\Users\\J554696\\Desktop\\Opportunity.csv'
df = pd.read_csv('Opportunity.csv',  encoding = "ISO-8859-1")
# Out:
# C:\Users\J554696\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (2,18,21,23,24,25,52,79,96,104,106,126,132,134,138,139,141,149,152,153,154,155,156,157,159,160,161,163) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#   Account_Development_Rep__c           AccountId Americas_Partner_Select__c  \
# 0                      Rep 1  0011600001l4gN3AAI                        NaN
# 1                      Rep 1  001G000001AwRnrIAF                        NaN
# 2                      Rep 2  0011600001l52ZIAAY                        NaN
# 3                        NaN  001A000000BdFfbIAF                        NaN
# 4                      Rep 3  001G000001kpDrdIAE                        NaN
#
#     Amount  Amount_Billed_To_Date__c  Approved_Discount__c  Audit_Flag__c  \
# 0  50000.0                         0                     0            NaN
# 1  50000.0                         0                     0            NaN
# 2  25000.0                         0                     0            NaN
# 3  51500.0                         0                     0            NaN
# 4  50000.0                         0                     0            NaN
#
#   Bill_To_Customer__c Business_Issues__c          CampaignId  \
# ...

# %%
information  = df.info(max_cols = 185, verbose=None)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4180 entries, 0 to 4179
# Data columns (total 185 columns):
# Account_Development_Rep__c                940 non-null object
# AccountId                                 4180 non-null object
# Americas_Partner_Select__c                1 non-null object
# Amount                                    3430 non-null float64
# Amount_Billed_To_Date__c                  4180 non-null int64
# Approved_Discount__c                      4180 non-null int64
# Audit_Flag__c                             0 non-null float64
# Bill_To_Customer__c                       222 non-null object
# Business_Issues__c                        476 non-null object
# CampaignId                                168 non-null object
# CDR__c                                    0 non-null float64
# CDT_Next_Step__c                          0 non-null float64
# CDT_Next_Step_Due_Date__c                 0 non-null float64
# ...

# %%
null_columns=df.columns[df.isnull().any()]
info_df = df[null_columns].isnull().sum().sort_values(ascending = False)

# %%
drop_col = pd.DataFrame(info_df , columns= ['Null_count'])

# %%
drop_col[drop_col['Null_count'] > 3548].index
# Out:
# Index(['Partner_Expected_Deal_Closure_Date__c', 'Quote_Number_Synced__c',
#        'Deal_Registration_Number__c', 'Partner_Website_URL__c',
#        'Partner_Street_Address__c', 'Partner_State_Province__c',
#        'Partner_Promo_Code__c', 'Partner_Phone__c', 'Partner_Lead_ID__c',
#        'Partner_Lead_Description__c',
#        ...
#        'What_Happens_Next__c', 'Spigit_Lost_Reason__c', 'Description',
#        'Product_Issues__c', 'Signature_Process_Description__c',
#        'Business_Issues__c', 'Who_signs_contracts__c', 'What_is_major_risk__c',
#        'Impending_Event__c', 'LeadSource'],
#       dtype='object', length=108)

# %%
df.drop(drop_col[drop_col['Null_count'] > 3548].index , axis = 1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4180 entries, 0 to 4179
# Data columns (total 77 columns):
# Account_Development_Rep__c            940 non-null object
# AccountId                             4180 non-null object
# Amount                                3430 non-null float64
# Amount_Billed_To_Date__c              4180 non-null int64
# Approved_Discount__c                  4180 non-null int64
# Closed_Lost_Reason__c                 1396 non-null object
# CloseDate                             4180 non-null object
# Collaboration_Primary_Interest__c     4180 non-null bool
# CreatedById                           4180 non-null object
# CreatedDate                           4180 non-null object
# CurrencyIsoCode                       4180 non-null object
# Current_State__c                      998 non-null object
# Days_in_Quarter__c                    4180 non-null int64
# Due_Date__c                           2356 non-null object
# ...

# %%
df.head()
# Out:
#   Account_Development_Rep__c           AccountId   Amount  \
# 0                      Rep 1  0011600001l4gN3AAI  50000.0
# 1                      Rep 1  001G000001AwRnrIAF  50000.0
# 2                      Rep 2  0011600001l52ZIAAY  25000.0
# 3                        NaN  001A000000BdFfbIAF  51500.0
# 4                      Rep 3  001G000001kpDrdIAE  50000.0
#
#    Amount_Billed_To_Date__c  Approved_Discount__c Closed_Lost_Reason__c  \
# 0                         0                     0                   NaN
# 1                         0                     0                   NaN
# 2                         0                     0                   NaN
# 3                         0                     0                   NaN
# 4                         0                     0                   NaN
#
#     CloseDate  Collaboration_Primary_Interest__c         CreatedById  \
# 0  30-06-2015                              False  005G00000066nbrIAA
# ...
